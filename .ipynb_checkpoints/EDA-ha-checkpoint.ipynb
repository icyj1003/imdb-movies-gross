# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data/data_preprocessed.csv")

# %%
df.shape
# Out:
# (22245, 21)

# %%
df.head(10)
# Out:
#                    title                                              casts  \
# 0                Bóng Ma         Daniel Craig,Christoph Waltz,Léa Seydoux,,
# 1              Halloween        Jamie Lee Curtis,Judy Greer,Andi Matichak,,
# 2                  Venom            Tom Hardy,Michelle Williams,Riz Ahmed,,
# 3                Skyfall         Daniel Craig,Javier Bardem,Naomie Harris,,
# 4        The Night House   Rebecca Hall,Sarah Goldberg,Vondie Curtis-Hall,,
# 5             Knives Out            Daniel Craig,Chris Evans,Ana de Armas,,
# 6  De slag om de Schelde            Gijs Blom,Jamie Flatters,Susan Radder,,
# 7  Promising Young Woman            Carey Mulligan,Bo Burnham,Alison Brie,,
# 8           Gisaengchung          Kang-ho Song,Sun-kyun Lee,Yeo-jeong Cho,,
# 9                365 dni  Anna Maria Sieklucka,Michele Morrone,Bronislaw...
#
#                          directors  \
# 0                      Sam Mendes,
# 1              David Gordon Green,
# 2                 Ruben Fleischer,
# 3                      Sam Mendes,
# 4                  David Bruckner,
# 5                    Rian Johnson,
# 6     Matthijs van Heijningen Jr.,
# 7                 Emerald Fennell,
# 8                    Bong Joon Ho,
# 9  Barbara Bialowas,Tomasz Mandes,
#
#                                              writers  \
# 0               John Logan,Neal Purvis,Robert Wade,,
# 1           John Carpenter,Debra Hill,Jeff Fradley,,
# 2        Jeff Pinkner,Scott Rosenberg,Kelly Marcel,,
# 3               Neal Purvis,Robert Wade,John Logan,,
# 4                       Ben Collins,Luke Piotrowski,
# 5                                      Rian Johnson,
# 6  Paula van der Oest,Jesse Maiman,Pauline van Ma...
# 7                                   Emerald Fennell,
# 8                          Bong Joon Ho,Jin-won Han,
# 9    Tomasz Klimala,Tomasz Mandes,Barbara Bialowas,,
#
#                                  genres certificate  \
# 0            Action,Adventure,Thriller,         NaN
# 1                Crime,Horror,Thriller,         C18
# 2              Action,Adventure,Sci-Fi,         NaN
# 3            Action,Adventure,Thriller,         C13
# 4              Horror,Mystery,Thriller,         C16
# 5  Comedy,Crime,Drama,Mystery,Thriller,         C13
# 6                            Drama,War,         C18
# 7                 Crime,Drama,Thriller,         C16
# 8                Comedy,Drama,Thriller,         C13
# 9                        Drama,Romance,         C18
#
#                                  countries_of_origin  \
# 0  United Kingdom,United States,Austria,Mexico,It...
# 1                      United States,United Kingdom,
# 2                               China,United States,
# 3               United Kingdom,United States,Turkey,
# 4                      United Kingdom,United States,
# 5                                     United States,
# 6                     Netherlands,Lithuania,Belgium,
# 7                      United Kingdom,United States,
# 8                                       South Korea,
# 9                                            Poland,
#
#                                            languages  \
# 0             English,Spanish,Italian,German,French,
# 1                                           English,
# 2                            English,Mandarin,Malay,
# 3  English,Turkish,Shanghainese,Portuguese,Japanese,
# 4                                           English,
# 5                             English,Spanish,Hindi,
# 6                              Dutch,German,English,
# 7                                           English,
# 8                                    Korean,English,
# 9                            Polish,English,Italian,
#
#                                 production_companies  \
# 0                      B24,Columbia Pictures,Danjaq,
# 1  Blumhouse Productions,Miramax,Night Blade Hold...
# 2  Avi Arad Productions,Columbia Pictures,Marvel ...
# 3  Metro-Goldwyn-Mayer (MGM),Columbia Pictures,Da...
# 4                          Anton,Phantom Four Films,
# 5     Lionsgate,Media Rights Capital (MRC),T-Street,
# 6  Levitate Film,Caviar Films,Evangelische Omroep...
# 7  FilmNation Entertainment,Focus Features,LuckyC...
# 8                     CJ Entertainment,Barunson E&A,
# 9                      Ekipa,Future Space,Next Film,
#
#                                            sound_mix  ...  color       budget  \
# 0          Dolby Digital,Datasat,Dolby Surround 7.1,  ...  Color  245000000.0
# 1                         Dolby Digital,Dolby Atmos,  ...  Color   10000000.0
# 2             Dolby Atmos,Auro 11.1,Sonics-DDP,SDDS,  ...  Color  100000000.0
# 3  Dolby Digital,Datasat,SDDS,Sonics-DDP,Dolby Su...  ...  Color  200000000.0
# 4                                                NaN  ...  Color          NaN
# 5      Dolby Digital,D-Cinema 48kHz 5.1,Dolby Atmos,  ...  Color   40000000.0
# 6                                       Dolby Atmos,  ...  Color   16240000.0
# 7                                       Dolby Atmos,  ...  Color          NaN
# 8                                       Dolby Atmos,  ...  Color   11400000.0
# 9                                            Stereo,  ...  Color          NaN
#
#    runtime  release_date  score  votes  user_reviews  critic_reviews  \
# 0    148.0        2015.0    6.8  408.0        1200.0           462.0
# 1    106.0        2018.0    6.5  133.0        1900.0           499.0
# 2    112.0        2018.0    6.7  415.0        3800.0           427.0
# 3    143.0        2012.0    7.8  659.0        1600.0           542.0
# 4    107.0        2021.0    6.5   15.0         262.0           133.0
# 5    130.0        2019.0    7.9  537.0        2700.0           480.0
# 6    124.0        2021.0    7.3    6.8          98.0            24.0
# 7    113.0        2021.0    7.5  133.0        1000.0           731.0
# 8    132.0        2019.0    8.6  670.0        3200.0           595.0
# 9    114.0        2020.0    3.3   68.0        1300.0            49.0
#
#    metascore  gross_worldwide
# 0       60.0     8.806815e+08
# 1       67.0     2.556149e+08
# 2       35.0     8.560852e+08
# 3       81.0     1.108569e+09
# 4       68.0     1.516366e+07
# 5       82.0     3.116056e+08
# 6        NaN     5.970683e+06
# 7       73.0     1.712278e+07
# 8       96.0     2.586700e+08
# 9        NaN     9.458590e+06
#
# [10 rows x 21 columns]

# %% [markdown]
# # Directors

# %%
fig_dims = (10, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(y="directors",data=df, order=df.directors.value_counts().index[0:20]).set_title('Director Analysis')
# Out:
# Text(0.5, 1.0, 'Director Analysis')

# %%
fig_dims = (40, 25)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(y=df["gross_worldwide"], x=df["directors"],showfliers=True, order=df.directors.value_counts().index[0:20])
plt.xticks(fontsize=20)
plt.xticks(rotation=50)  
plt.yticks(fontsize=20)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# # Writers

# %%
fig_dims = (10, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(y="writers",data=df, order=df.writers.value_counts().index[0:20]).set_title('Writers Analysis')
# Out:
# Text(0.5, 1.0, 'Writers Analysis')

# %%
fig_dims = (30, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot( y=df["gross_worldwide"], x=df["writers"],showfliers=True, order=df.writers.value_counts().index[0:20])
plt.xticks(fontsize=20)
plt.xticks(rotation=50)
plt.yticks(fontsize=20)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# # release_date

# %%
fig_dims = (10, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(y="release_date",data=df, order=df.release_date.value_counts().index[0:12]).set_title('Yearly Analysis')
# Out:
# Text(0.5, 1.0, 'Yearly Analysis')

# %%
fig_dims = (15, 15)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot( y=df["gross_worldwide"], x=df["release_date"],showfliers=False, order=df.release_date.value_counts().index[0:12])
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# *   Doanh thu trong khoảng thời gian [2010,2015] có sự phân bố khá là tương đồng và có sự giao động lớn.
# *   Doanh thu trong khoảng thời gian [2016,2020] có sự phân bố khá là
# tương đồng và có xu hướng thấp hơn và ít giao động doanh thu của nhóm [2010,2015]. (Có thể là do giai đoạn này công nghệ đã phát triển, internet có khắp mọi nơi nên người xem không cần phải lên rạp mà có thể chờ có trên internet rồi coi để giảm chi phí nên doanh thu thấp hơn so với giai đoạn trước).

# %% [markdown]
# #Countries

# %%
fig_dims = (10, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(y="countries_of_origin",data=df, order=df.countries_of_origin.value_counts().index[0:20]).set_title('Contries Analysis')
# Out:
# Text(0.5, 1.0, 'Contries Analysis')

# %%
fig_dims = (20, 50)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot( y=df["gross_worldwide"], x=df["countries_of_origin"],showfliers=False, order=df.countries_of_origin.value_counts().index[0:20])
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# # languages

# %%
fig_dims = (10, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(y="languages",data=df, order=df.languages.value_counts().index[0:20]).set_title('Languages Analysis')
# Out:
# Text(0.5, 1.0, 'Languages Analysis')

# %%
plt.figure(figsize=(50,50))
sns.pointplot(x='languages',y='gross_worldwide',kind='bar',height=5,data=df,order=df.languages.value_counts().index[0:20],hue='release_date')

plt.title('...')
# Out:
# Text(0.5, 1.0, '...')

# %%
fig_dims = (20, 40)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(y=df["gross_worldwide"], x=df["languages"],showfliers=False, order=df.languages.value_counts().index[0:20])
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
result
# Out:
#                          title  languages  gross_worldwide  soluong
# 0                      Bóng Ma    English      880681519.0        5
# 1                      Bóng Ma    Spanish      880681519.0        5
# 2                      Bóng Ma    Italian      880681519.0        5
# 3                      Bóng Ma     German      880681519.0        5
# 4                      Bóng Ma     French      880681519.0        5
# ...                        ...        ...              ...      ...
# 30281  And the Oskar Goes To..  Malayalam         116304.0        2
# 30282  And the Oskar Goes To..     Telugu         116304.0        2
# 30283    London Paris New York      Hindi         196317.0        1
# 30284                    Jilla      Tamil       11050289.0        2
# 30285                    Jilla  Malayalam       11050289.0        2
#
# [30286 rows x 4 columns]

# %%
#Kiểm tra số lượng ngôn ngữ có tương quan với doanh thu hay không?
result[["gross_worldwide","soluong"]].corr()
# Out:
#                  gross_worldwide  soluong
# gross_worldwide          1.00000  0.14025
# soluong                  0.14025  1.00000

# %% [markdown]
# Số lượng ngôn ngữ có sự tương quan đến doanh thu

# %% [markdown]
# # certificate

# %%
df["certificate"].value_counts()
# Out:
# Unrated    2850
# C13        2657
# C16        1875
# P           911
# C18         592
# Name: certificate, dtype: int64

# %%
sns.boxplot( y=df["gross_worldwide"], x=df["certificate"],showfliers=False)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
sns.boxplot( y=df["gross_worldwide"], x=df["color"],showfliers=False)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# # Color với Certificate

# %%
plt.subplot()
sns.pointplot(x='certificate',y='gross_worldwide',kind='bar',height=5,data=df,hue='color')
plt.title('...')
# Out:
# Text(0.5, 1.0, '...')

# %% [markdown]
# # Genres

# %%
fig_dims = (10, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(y="genres",data=df, order=df.genres.value_counts().index[0:20]).set_title('Genres Analysis')
# Out:
# Text(0.5, 1.0, 'Genres Analysis')

# %%
fig_dims = (30, 30)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(y=df["gross_worldwide"], x=df['genres'],showfliers=False,order=df.genres.value_counts().index[0:13])
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# # aspect_ratio

# %%
df['aspect_ratio'].value_counts()
# Out:
# 2.35:1         5798
# 1.85:1         2797
# 2.39:1         1595
# 1.78:1          816
# 1.66:1          101
# 1.33:1           72
# 2.00:1           53
# 1.37:1           39
# 2.40:1           23
# 2:1              22
# 2.66:1           22
# 2.20:1           16
# 1.90:1           14
# 2.55:1            8
# 2.4:1             7
# 1.50:1            5
# 2.76:1            5
# 2:39              5
# 1:1               4
# 1.55:1            4
# cinemascope       3
# 2.25:1            2
# 1.89:1            2
# 3:1               2
# 2.11:1            2
# 2.10:1            2
# 1.61:1            1
# 1.95:1            1
# circular          1
# 2.37:1            1
# 3.2:1             1
# 2.80:1            1
# 1.90.1            1
# 1.77:1            1
# 1.19:1            1
# 1.20:1            1
# 1.40:1            1
# 1.85.1            1
# 2.21:1            1
# 2.12:1            1
# 1:1.85            1
# 2.38:1            1
# 3.66:1            1
# 2.16:1            1
# tondoscope        1
# 1:66              1
# 1.56:1            1
# 2.41:1            1
# 1:2.35            1
# 2.77:1            1
# 1.00:1            1
# 2.2:1             1
# 2.22:1            1
# Name: aspect_ratio, dtype: int64

# %%
df_test = df[['aspect_ratio', 'release_date','gross_worldwide']]
df_gr = df_test.groupby(['aspect_ratio', 'release_date'], as_index = False).mean()

# %%
fig_dims = (20, 30)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(y=df["gross_worldwide"], x=df["aspect_ratio"],showfliers=False, order=df.aspect_ratio.value_counts().index[0:13])
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# #Aspect_ratio với Release_date

# %%
plt.figure(figsize=(50,50))
sns.pointplot(x='aspect_ratio',y='gross_worldwide',kind='bar',height=5,data=df,order=df.aspect_ratio.value_counts().index[0:9],hue='release_date', figsize=(50,50))
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.title('...')
plt.legend(fontsize=30)
plt.show()

# %%
fig_dims = (80, 50)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(y=df["gross_worldwide"], x=df["aspect_ratio"],showfliers=False,hue=df['release_date'], order=df.aspect_ratio.value_counts().index[0:9])
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
fig_dims = (40, 50)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(y=df["gross_worldwide"], x=df["aspect_ratio"],showfliers=False,hue=df['certificate'], order=df.aspect_ratio.value_counts().index[0:8])
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
sns.pointplot(x='certificate',y='gross_worldwide',kind='bar',height=5,data=df,hue='release_date', figsize=(40,20))
plt.title('...')
# Out:
# Text(0.5, 1.0, '...')
